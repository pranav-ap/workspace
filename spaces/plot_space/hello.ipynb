# %%
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# # Simple Version

# %%
# Create a simple plot, without the semi-colon
plt.plot()
# Out:
# []

# %%
# With the semi-colon
plt.plot();

# %%
# You could use plt.show() if you want
plt.plot()
plt.show()

# %%
# Let's add some data
plt.plot([1, 2, 3, 4]);

# %%
# Now a y-value too!

x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

plt.plot(x, y);

# %% [markdown]
# # OOPS Version

# %%
# Create a Figure and multiple potential Axes and add some data
fig, ax = plt.subplots(figsize=(10,10))
ax.plot(x, y)
ax.set(title="Sample Simple Plot", xlabel="x-axis", ylabel="y-axis");

# %% [markdown]
# # Common Plots

# %%
import numpy as np

# %%
# Create an array
x = np.linspace(0, 10, 100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %% [markdown]
# ## Line Plot

# %%
# The default plot is line
fig, ax = plt.subplots()
ax.plot(x, x**2);

# %% [markdown]
# ## Scatter

# %%
# Need to recreate our figure and axis instances when we want a new figure
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %% [markdown]
# ## Bar Plot

# %%
# You can make plots from a dictionary
nut_butter_prices = {"Almond butter": 10,
                     "Peanut butter": 8,
                     "Cashew butter": 12}

fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())

ax.set(title="Dan's Nut Butter Store", ylabel="Price ($)");

# %% [markdown]
# ## Histogram

# %%
# Make some data from a normal distribution
x = np.random.randn(1000) # pulls data from a normal distribution

fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# # Multiple Subplots

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

# Index the ax variable to plot data
ax[0, 0].plot(x, x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1, 1].hist(np.random.randn(1000));

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Series

# %%
# Start with some dummy data
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2024', periods=1000))

# Note: ts = short for time series (data over time)
ts
# Out:
# 2024-01-01    1.052238
# 2024-01-02    1.306849
# 2024-01-03    0.337267
# 2024-01-04   -0.285054
# 2024-01-05    0.337630
#                 ...
# 2026-09-22   -0.856249
# 2026-09-23   -0.090035
# 2026-09-24    0.153248
# 2026-09-25   -0.889517
# 2026-09-26    0.579027
# Freq: D, Length: 1000, dtype: float64

# %%
# Add up the values cumulatively
ts.cumsum()
# Out:
# 2024-01-01    1.052238
# 2024-01-02    2.359087
# 2024-01-03    2.696353
# 2024-01-04    2.411300
# 2024-01-05    2.748930
#                 ...
# 2026-09-22   -5.053748
# 2026-09-23   -5.143782
# 2026-09-24   -4.990534
# 2026-09-25   -5.880051
# 2026-09-26   -5.301024
# Freq: D, Length: 1000, dtype: float64

# %%
# Plot the values over time with a line plot 
ts.cumsum().plot(kind="line");

# %% [markdown]
# ## Data Frame

# %%
# Import the car sales data 
car_sales = pd.read_csv("../data/car-sales.csv")

# Remove price column symbols
car_sales["Price"] = car_sales["Price"].str.replace('[$\\,\\.]', '', regex=True)
# Remove last two zeros
car_sales["Price"] = car_sales["Price"].str[:-2]
# Add a date column
car_sales["Sale Date"] = pd.date_range("1/1/2024", periods=len(car_sales))
# Make total sales column
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()

car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2024-01-01         4000
# 1   Honda    Red          87899      4   5000 2024-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2024-01-03        16000
# 3     BMW  Black          11179      5  22000 2024-01-04        38000
# 4  Nissan  White         213095      4   3500 2024-01-05        41500
# 5  Toyota  Green          99213      4   4500 2024-01-06        46000
# 6   Honda   Blue          45698      4   7500 2024-01-07        53500
# 7   Honda   Blue          54738      4   7000 2024-01-08        60500
# 8  Toyota  White          60000      4   6250 2024-01-09        66750
# 9  Nissan  White          31600      4   9700 2024-01-10        76450

# %% [markdown]
# ## Line Plot

# %%
car_sales.plot(x='Sale Date', y='Total Sales');

# %% [markdown]
# ## Scatter

# %%
car_sales["Price"] = car_sales["Price"].astype(int)

# Plot a scatter plot
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %% [markdown]
# ## Bar Plot

# %%
# Create 10 random samples across 4 columns
x = np.random.rand(10, 4)
x
# Out:
# array([[0.79313862, 0.97542538, 0.59389627, 0.18921239],
#        [0.35437645, 0.7550639 , 0.58595757, 0.82122702],
#        [0.98103301, 0.24089942, 0.64295357, 0.46785948],
#        [0.8093529 , 0.19225978, 0.17595209, 0.39227064],
#        [0.97812422, 0.06430938, 0.18375091, 0.76429428],
#        [0.52049638, 0.1094548 , 0.6815274 , 0.9490455 ],
#        [0.7105799 , 0.7454297 , 0.45095893, 0.17792119],
#        [0.20421997, 0.34459125, 0.38160345, 0.51724943],
#        [0.38520764, 0.35572781, 0.35988762, 0.99599076],
#        [0.31214426, 0.18607629, 0.75535349, 0.14781249]])

# %%
# Turn the data into a DataFrame
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.793139  0.975425  0.593896  0.189212
# 1  0.354376  0.755064  0.585958  0.821227
# 2  0.981033  0.240899  0.642954  0.467859
# 3  0.809353  0.192260  0.175952  0.392271
# 4  0.978124  0.064309  0.183751  0.764294
# 5  0.520496  0.109455  0.681527  0.949046
# 6  0.710580  0.745430  0.450959  0.177921
# 7  0.204220  0.344591  0.381603  0.517249
# 8  0.385208  0.355728  0.359888  0.995991
# 9  0.312144  0.186076  0.755353  0.147812

# %%
# Plot a bar chart
df.plot.bar();

# %%
# car_sales.plot.bar() # dont do this
# Out:
# <Axes: >

# %%
# Plot a bar chart from car_sales DataFrame
car_sales.plot(x="Make", 
               y="Odometer (KM)", 
               kind="bar");

# %% [markdown]
# ## Histogram

# %%
car_sales["Odometer (KM)"].plot.hist(bins=20);

# %%
car_sales["Odometer (KM)"].plot(kind="hist", bins=20);

# %% [markdown]
# # More Advanced

# %%
# Import the heart disease dataset
heart_disease = pd.read_csv("../data/heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Perform data analysis on patients over 50
over_50 = heart_disease[heart_disease["age"] > 50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# 4        2   0     2       1
# 5        1   0     1       1
# 6        1   0     2       1
# ..     ...  ..   ...     ...
# 297      1   2     1       0
# 298      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [208 rows x 14 columns]

# %% [markdown]
# ## Scatter

# %%
# Create Figure and Axes instance
fig, ax = plt.subplots(figsize=(10, 6))

# Plot data directly to the Axes instance
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"],  # Colour the data with the "target" column
                     cmap="viridis") # default cmap value
                      
# Customize the plot parameters 
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");

# Setup the legend
ax.legend(*scatter.legend_elements(), title="Target");

# %% [markdown]
# ## Multiple Subplots

# %%
# Setup plot (2 rows, 1 column)
fig, (ax0, ax1) = plt.subplots(nrows=2, # 2 rows
                               ncols=1, # 1 column 
                               sharex=True, # both plots should use the same x-axis 
                               figsize=(10, 8))

# ---------- Axis 0: Heart Disease and Cholesterol Levels ----------

# Add data for ax0
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"],
                      cmap="viridis")
# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol",
        xlim=[50, 80]) # set the x-axis ranges 

ax0.legend(*scatter.legend_elements(), title="Target")

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(), 
            color='b', 
            linestyle='--', 
            label="Average")

# ---------- Axis 1: Heart Disease and Max Heart Rate Levels ----------

# Add data for ax1
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"],
                      cmap="viridis")

# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age", # Only set here
        ylabel="Max Heart Rate",
        ylim=[60, 220]) # change the y-axis range

ax1.legend(*scatter.legend_elements(), title="Target")

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color='b', 
            linestyle='--', 
            label="Average")

# Title the figure
fig.suptitle('Heart Disease Analysis', 
             fontsize=16, 
             fontweight='bold');

# %%
# Save the file
fig.savefig(fname="../assets/heart-disease-analysis.png",
            dpi=100)

# %% [markdown]
# # Styles

# %%
# Check the available styles
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# Change the style of our future plots
plt.style.use("seaborn-v0_8-whitegrid")

# %%
# Plot the same plot as before
car_sales["Price"].plot();

# %% [markdown]
# # Seaborn

# %%
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()

# Load an example dataset
tips = sns.load_dataset("tips")

# %% [markdown]
# ## Scatter

# %%
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)

# %% [markdown]
# ## Line Plot

# %%
dots = sns.load_dataset("dots")
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate", col="align",
    hue="choice", size="coherence", style="choice",
    facet_kws=dict(sharex=False),
);
